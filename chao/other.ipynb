# %%
import numpy as np

# %%
b = np.array([[1,2,3],[4,5,6]])

# %%
b.shape
# Out:
# (2, 3)

# %%
b.reshape(3,2)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
b.reshape((-1,3))
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a = np.array([1,2,3,4,5,6])
a.reshape(-1, 1)
b = [0,2,1,1,1,2,2,2]
c = a[b]
c
# Out:
# array([1, 3, 2, 2, 2, 3, 3, 3])

# %%
import tensorflow as tf

# %%
a = tf.add(3,5)

sess = tf.Session()
print(sess.run(a))
sess.close()
# Out:
# 8
